# %% [markdown]
# In Natural Language Processing (NLP), several standardized datasets serve as benchmarks for different NLP tasks. Here are some popular ones:

# %% [markdown]
# Text Classification

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Named Entity Recognition (NER)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Machine Translation

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Question Answering (QA)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Text Generation (Language Modeling)

# %% [markdown]
# ![image.png](attachment:image.png)
